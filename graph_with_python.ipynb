# %% [markdown]
# <a href="https://colab.research.google.com/github/elaamranisoufiane/Graphs-with-python/blob/main/graph_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/KeithGalli/matplotlib_tutorial.git
# Out:
# Cloning into 'matplotlib_tutorial'...
# remote: Enumerating objects: 17, done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 17
# Unpacking objects: 100% (17/17), done.

# %%
import matplotlib.pyplot as plt
import numpy as pn
import pandas as pd

# %%
gas = pd.read_csv('/content/sample_data/gas_prices.csv')

# %%
gas
# Out:
#     Year  Australia  Canada  France  ...  Mexico  South Korea    UK   USA
# 0   1990        NaN    1.87    3.63  ...    1.00         2.05  2.82  1.16
# 1   1991       1.96    1.92    3.45  ...    1.30         2.49  3.01  1.14
# 2   1992       1.89    1.73    3.56  ...    1.50         2.65  3.06  1.13
# 3   1993       1.73    1.57    3.41  ...    1.56         2.88  2.84  1.11
# 4   1994       1.84    1.45    3.59  ...    1.48         2.87  2.99  1.11
# 5   1995       1.95    1.53    4.26  ...    1.11         2.94  3.21  1.15
# 6   1996       2.12    1.61    4.41  ...    1.25         3.18  3.34  1.23
# 7   1997       2.05    1.62    4.00  ...    1.47         3.34  3.83  1.23
# 8   1998       1.63    1.38    3.87  ...    1.49         3.04  4.06  1.06
# 9   1999       1.72    1.52    3.85  ...    1.79         3.80  4.29  1.17
# 10  2000       1.94    1.86    3.80  ...    2.01         4.18  4.58  1.51
# 11  2001       1.71    1.72    3.51  ...    2.20         3.76  4.13  1.46
# ...

# %%
from IPython.core.pylabtools import figsize
plt.figure(figsize=(10,5))
plt.title('Gras prices in US $')

plt.plot(gas.Year, gas.USA, label='United state')
plt.plot(gas['Year'],gas['South Korea'] , label='south korea')

plt.xticks(gas.Year)

plt.legend()
plt.show()
print(gas.Year)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-e42d5fb9571b> in <module>()
#      10 for country in gas:
#      11   if country != 'Year':
# ---> 12     plt.plot(gas.Year, gas.country, marker='.')
#      13
#      14
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'country'
